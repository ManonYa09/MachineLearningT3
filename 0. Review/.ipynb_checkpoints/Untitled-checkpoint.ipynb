# %%
import pandas as pd

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ManonYa09/Machine_Learning_G3/refs/heads/main/Dataset/2.%20Bank%20Customer%20Churn%20Prediction.csv')

# %%
df.sample( n = 10) ## iloc, loc, [1columns],[[]]
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 1594     15576676           706  Germany  Female   28       6  124923.35
# 6166     15567431           773   France    Male   64       2  145578.28
# 3275     15800215           658   France    Male   25       3       0.00
# 7758     15684358           711   France    Male   41       3       0.00
# 4871     15575858           763   France    Male   40       3       0.00
# 2767     15747265           598  Germany  Female   27      10  171283.91
# 1687     15589348           850    Spain    Male   37       4  137204.77
# 5250     15720820           462  Germany  Female   24       9   69881.09
# 3903     15678129           643    Spain  Female   45       9  150840.03
# 410      15566594           709    Spain    Male   23      10       0.00
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 1594                2            1              1          50299.14      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df['age'] = df['age'].astype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  object
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
Categorical
# Out:
# ['country', 'gender']

# %%
df[Categorical]
# Out:
#       country  gender
# 0      France  Female
# 1       Spain  Female
# 2      France  Female
# 3      France  Female
# 4       Spain  Female
# ...       ...     ...
# 9995   France    Male
# 9996   France    Male
# 9997   France  Female
# 9998  Germany    Male
# 9999   France  Female
#
# [10000 rows x 2 columns]

# %%
df[['country','gender' ]]
# Out:
#       country  gender
# 0      France  Female
# 1       Spain  Female
# 2      France  Female
# 3      France  Female
# 4       Spain  Female
# ...       ...     ...
# 9995   France    Male
# 9996   France    Male
# 9997   France  Female
# 9998  Germany    Male
# 9999   France  Female
#
# [10000 rows x 2 columns]

# %%
x = df.drop(columns='churn')
y = df['churn']

# %%
Categorical= ['country', 'gender']
Numberical = ['credit_score', 'age','tenure','balance'
              'products_number',	'credit_card',	
              'active_member',	'estimated_salary'	]
columns_to_drop = ['customer_id']
target = 'churn'

# %%
df1 = df.copy()

# %% [markdown]
# ### 3.Data Preprocessing or Feature Engineering

# %%
Preprocessing Pipeline --> input : auto endcoding (covnet categorical to numberical)
                                    auto scaling
                                    training

# %% [markdown]
# #### 3.1 Cagtegorical Or String
#
# convert Categorical  to Numerical

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
##df['gender'].replace({'Female':1, 'Male':0})

# %%
# df[[Categorical[1]]] ## 1-d

# %%
# df[Categorical]

# %%
# df['gender'].value_counts()

# %%
# df['country'].value_counts()

# %%
df1[Categorical] = OrdinalEncoder().fit_transform(df1[Categorical])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  float64
#  3   gender            10000 non-null  float64
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(4), int64(8)
# memory usage: 937.6 KB

# %% [markdown]
# #### 3.2 Numerical

# %%
Numberical
# Out:
# ['credit_score',
#  'age',
#  'tenure',
#  'balanceproducts_number',
#  'credit_card',
#  'active_member',
#  'estimated_salary']

# %%
Function learn data

# %%
x -> model ,<-- y

# %%
x = df1.drop(columns='churn')
y = df1['churn']

# %% [markdown]
# ### Model Learning

# %%
from sklearn.linear_model import LinearRegression

# %%
Linear_model = LinearRegression()

# %%
Linear_model.fit(x, y) # Value Error : could not convert string to float
# Out:
# LinearRegression()

# %%
Linear_model
# Out:
# LinearRegression()

# %% [markdown]
# ### Evaulation Model

# %%
metrics,

# %% [markdown]
# ### End User

# %%
Data Science Team + Customer Life Cycle +

# %%
- Data Science Team: Deployment Local Network 
- Company: Deployment Local Network
- Public:

# %%
x.shape 12
# Out:
# (10000, 11)

# %%
### Strcuture Data 
Overfitting 
model training Acc = 100%, 
traking = 10%, 20%
100 rows = 10

Uderfitting  = model training Acc = 10%, 
Tracking = 50,

# %%
x: input variables
y : output

y  = a+ bx

# %%
y = 2x+ 1
x = 3
x= -2 => y = -3

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
mean = df['age'].mean()

# %%
a1 = mean - x0 = 38-42= -4
a2 = mean - x3 = 0....
(a1) + (a2)

# %%
df['age']  #, xi = 
#x0 = 42
x1 = 41
x2 = 42
x3 = 38
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: age, Length: 10000, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# ### Number or Numerical, Categorical

# %%
df.describe()['age']
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: age, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
75: 44, 
age: 101
age 500 year
-1 age
-2
age 16

# %%
(0, 1, 2, 3, )
(-3, -2, -1, -0)

# %%
df.shape
# Out:
# (10000, 12)

# %%
100*df[df['age']>=70].shape[0]/len(df)
# Out:
# 1.51

# %%
df[df['age']>=70].shape[-2]
# Out:
# 151

# %%
2+1
# Out:
# 3

# %%
3+4
# Out:
# 7

# %%
age: 1000

# %%
fig,ax = plt.subplots(figsize = (12, 4))
sns.boxplot(x = df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
fig,ax = plt.subplots(1,2, figsize = (12, 4))
sns.histplot(x = df['age'], ax = ax[1])
sns.boxplot(x = df['age'], ax = ax[0])
sns.despine()

# %%
df['country'].value_counts()
# Out:
# country
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %% [markdown]
# #### Diagnostics Analysis

# %%
df.nunique()
# Out:
# customer_id         10000
# credit_score          460
# country                 3
# gender                  2
# age                    70
# tenure                 11
# balance              6382
# products_number         4
# credit_card             2
# active_member           2
# estimated_salary     9999
# churn                   2
# dtype: int64

# %%
target = 'churn' ## dependent varaible
numerical = []
categorical = []
column_drop = ['customer_id']

for column in df.columns:
    if column in column_drop:
        continue
    elif column==target:
        continue
    elif df[column].nunique()>=4:
        numerical.append(column)
    else:
        categorical.append(column)

# %%
df[numerical].corr()
# Out:
#                   credit_score       age    tenure   balance  products_number  \
# credit_score          1.000000 -0.003965  0.000842  0.006268         0.012238
# age                  -0.003965  1.000000 -0.009997  0.028308        -0.030680
# tenure                0.000842 -0.009997  1.000000 -0.012254         0.013444
# balance               0.006268  0.028308 -0.012254  1.000000        -0.304180
# products_number       0.012238 -0.030680  0.013444 -0.304180         1.000000
# estimated_salary     -0.001384 -0.007201  0.007784  0.012797         0.014204
#
#                   estimated_salary
# credit_score             -0.001384
# age                      -0.007201
# tenure                    0.007784
# balance                   0.012797
# products_number           0.014204
# estimated_salary          1.000000

# %%
df['churn'] = df['churn'].replace({1:'Yes', 0:'No'})

# %%
df1 = df[numerical]

# %%
df1[target] = df[target]

# %%
sns.pairplot(df1, hue = 'churn')

# %% [markdown]
# #### Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

# %%
# df['credit_score'].dtype

# %%
categorical
# Out:
# ['country', 'gender', 'credit_card', 'active_member']

# %%
numerical
# Out:
# ['credit_score',
#  'age',
#  'tenure',
#  'balance',
#  'products_number',
#  'estimated_salary']

# %%
df[numerical] = StandardScaler().fit_transform(df[numerical])

# %%
1.000050e+00
# Out:
# 1.00005

# %%
2.2e-16

# %%
10**-3 = 0.001

# %%
10**-4 = 1/10**4

# %%
2.2 * 10**(-16)

# %%
2.318146e-16
# Out:
# 2.318146e-16

# %%
df[numerical].describe()
# Out:
#        credit_score           age        tenure       balance  \
# count  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04
# mean  -4.824585e-16  2.318146e-16 -1.078249e-16 -6.252776e-17
# std    1.000050e+00  1.000050e+00  1.000050e+00  1.000050e+00
# min   -3.109504e+00 -1.994969e+00 -1.733315e+00 -1.225848e+00
# 25%   -6.883586e-01 -6.600185e-01 -6.959818e-01 -1.225848e+00
# 50%    1.522218e-02 -1.832505e-01 -4.425957e-03  3.319639e-01
# 75%    6.981094e-01  4.842246e-01  6.871299e-01  8.199205e-01
# max    2.063884e+00  5.061197e+00  1.724464e+00  2.795323e+00
#
#        products_number  estimated_salary
# count     1.000000e+04      1.000000e+04
# mean      1.634248e-17     -2.877698e-17
# std       1.000050e+00      1.000050e+00
# min      -9.115835e-01     -1.740268e+00
# 25%      -9.115835e-01     -8.535935e-01
# 50%      -9.115835e-01      1.802807e-03
# 75%       8.077366e-01      8.572431e-01
# max       4.246377e+00      1.737200e+00

# %%
categorical
# Out:
# ['country', 'gender', 'credit_card', 'active_member']

# %%
OneHotEncoder().fit_transform(df[categorical]).toarray().shape
# Out:
# (10000, 9)

# %% [markdown]
# #### Statistics model

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
import statsmodels.api as sm

# %%
StandardScaler.fit_transform(numerical])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 StandardScaler.fit_transform(df[numerical])
#
# TypeError: TransformerMixin.fit_transform() missing 1 required positional argument: 'X'

# %%
categorical
# Out:
# ['country', 'gender', 'credit_card', 'active_member']

# %%
df[numerical]
# Out:
#       credit_score  age  tenure    balance  products_number  estimated_salary
# 0              619   42       2       0.00                1         101348.88
# 1              608   41       1   83807.86                1         112542.58
# 2              502   42       8  159660.80                3         113931.57
# 3              699   39       1       0.00                2          93826.63
# 4              850   43       2  125510.82                1          79084.10
# ...            ...  ...     ...        ...              ...               ...
# 9995           771   39       5       0.00                2          96270.64
# 9996           516   35      10   57369.61                1         101699.77
# 9997           709   36       7       0.00                1          42085.58
# 9998           772   42       3   75075.31                2          92888.52
# 9999           792   28       4  130142.79                1          38190.78
#
# [10000 rows x 6 columns]

# %%
numerical
# Out:
# ['credit_score',
#  'age',
#  'tenure',
#  'balance',
#  'products_number',
#  'estimated_salary']

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['churn'] ## 1: yes churn, 0: no  churn
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: churn, Length: 10000, dtype: int64

# %%
target = 'churn' ## dependent varaible
numerical = []
categorical = []
input_or_feature_inpendent = []
